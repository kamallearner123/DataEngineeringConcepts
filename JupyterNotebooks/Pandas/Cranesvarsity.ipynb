# %%
'''
Patterns

'''

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
df = sns.load_dataset('mpg')

# %%
print(df.describe())
print(df.info())
print(df.head())
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
df['model_year'].sort_values(ascending=False)
print(df.shape)
# Out:
# (398, 9)

# %%
df['model_year'].hist()
# Out:
# <Axes: >

# %%
df2 = df[['mpg', 'model_year']].copy()
print(df2['mpg'])

plt.plot(df2['model_year'], df2["mpg"], "r*")
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
print(df['mpg'].describe())
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
df['origin'].nunique()
# Out:
# 3

# %%
df['origin'].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
data = df['origin'].value_counts()
print(data)
plt.plot(data)
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 3
#       1 data = df['origin'].value_counts()
#       2 print(data)
# ----> 3 plt.plot(data, type='bar')
#
# File ~/Documents/virtualEnvs/DeepCode/lib/python3.13/site-packages/matplotlib/pyplot.py:3827, in plot(scalex, scaley, data, *args, **kwargs)
#    3819 @_copy_docstring_and_deprecators(Axes.plot)
#    3820 def plot(
#    3821     *args: float | ArrayLike | str,
#    (...)   3825     **kwargs,
#    3826 ) -> list[Line2D]:
# -> 3827     return gca().plot(
#    3828         *args,
#    3829         scalex=scalex,
#    3830         scaley=scaley,
#    3831         **({"data": data} if data is not None else {}),
#    3832         **kwargs,
#    3833     )
#
# ...

# %%
plt(df.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 plt(df.isnull().sum())
#
# TypeError: 'module' object is not callable

# %%
sns.scatterplot(x='cylinders', y='mpg', data=df)
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg'>

# %%
data = df[df['origin'].apply(lambda x: x.startswith("j"))]
print(data)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 14   24.0          4         113.0        95.0    2372          15.0
# 18   27.0          4          97.0        88.0    2130          14.5
# 29   27.0          4          97.0        88.0    2130          14.5
# 31   25.0          4         113.0        95.0    2228          14.0
# 53   31.0          4          71.0        65.0    1773          19.0
# ..    ...        ...           ...         ...     ...           ...
# 382  34.0          4         108.0        70.0    2245          16.9
# 383  38.0          4          91.0        67.0    1965          15.0
# 384  32.0          4          91.0        67.0    1965          15.7
# 385  38.0          4          91.0        67.0    1995          16.2
# 390  32.0          4         144.0        96.0    2665          13.9
#
#      model_year origin                   name
# 14           70  japan  toyota corona mark ii
# ...

# %%
print(df.groupby('cylinders')["mpg"].mean())
# Out:
# cylinders
# 3    20.550000
# 4    29.286765
# 5    27.366667
# 6    19.985714
# 8    14.963107
# Name: mpg, dtype: float64

# %%
df1 = df[df['origin']=='japan']
df2 = df[df['origin']=='europe']

final = pd.concat([df1, df2], axis = 1)
print(final)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 14   24.0        4.0         113.0        95.0  2372.0          15.0
# 18   27.0        4.0          97.0        88.0  2130.0          14.5
# 29   27.0        4.0          97.0        88.0  2130.0          14.5
# 31   25.0        4.0         113.0        95.0  2228.0          14.0
# 53   31.0        4.0          71.0        65.0  1773.0          19.0
# ..    ...        ...           ...         ...     ...           ...
# 354   NaN        NaN           NaN         NaN     NaN           NaN
# 359   NaN        NaN           NaN         NaN     NaN           NaN
# 360   NaN        NaN           NaN         NaN     NaN           NaN
# 375   NaN        NaN           NaN         NaN     NaN           NaN
# 394   NaN        NaN           NaN         NaN     NaN           NaN
#
#      model_year origin                   name   mpg  cylinders  displacement  \
# ...

# %%
print(df['origin'].unique())
# Out:
# ['usa' 'japan' 'europe']

# %%
df['mpg'].min()
# Out:
# np.float64(9.0)

# %%
df.iloc[df['mpg'].idxmin()]
# Out:
# mpg                  9.0
# cylinders              8
# displacement       304.0
# horsepower         193.0
# weight              4732
# acceleration        18.5
# model_year            70
# origin               usa
# name            hi 1200d
# Name: 28, dtype: object

# %%
df.sort_values(by="mpg")
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 28    9.0          8         304.0       193.0    4732          18.5
# 25   10.0          8         360.0       215.0    4615          14.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 124  11.0          8         350.0       180.0    3664          11.0
# ..    ...        ...           ...         ...     ...           ...
# 326  43.4          4          90.0        48.0    2335          23.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 325  44.3          4          90.0        48.0    2085          21.7
# 329  44.6          4          91.0        67.0    1850          13.8
# 322  46.6          4          86.0        65.0    2110          17.9
#
#      model_year  origin                  name
# 28           70     usa              hi 1200d
# ...
